# %%
import urllib
import urllib.request

from bs4 import BeautifulSoup

# %%
theurl="https://www.tripadvisor.com.sg/Hotel_Review-g294265-d301583-Reviews-Raffles_Hotel_Singapore-Singapore.html"

# %%
def make_soup(url):
    thepage=urllib.request.urlopen(theurl)
    soupdata=BeautifulSoup(thepage,"html.parser")
    return soupdata

# %%
def add_five(x):
    y=x+5
    return y

# %%
add_five(5)
# Out:
# 10

# %%
soup=make_soup(theurl)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <link data-rup="long_lived_global_legacy" href="https://static.tacdn.com/css2/long_lived_global_legacy-v21408265582b.css" rel="stylesheet" type="text/css"/>
#   <link href="https://static.tacdn.com/favicon.ico" id="favicon" rel="icon" type="image/x-icon"/>
#   <link as="font" crossorigin="" href="https://static.tacdn.com/css2/webfonts/TripAdvisor/TripAdvisor_Regular.woff2?v003.230" rel="preload" type="font/woff2"/>
#   <link color="#00a680" href="https://static.tacdn.com/img2/icons/ta_square.svg" rel="mask-icon" sizes="any">
#    <script data-rup="global_error" type="text/javascript">
# ...

# %%
j=1
for link in soup.find_all("div",{"class":"review-container"}):
    print(j)
    print(link.find('p').text)
    
    j=j+1
# Out:
# 1
# No one can go to Singapore without having a Singapore Sling at Raffles. A truly impressive building and gardens and everyone was so friendly and polite. The food was delicious and the choice of drinks was enormous.......good cocktails, etc..
# 2
# everyone said you have to stay at Raffles and I'm glad I did. There are plenty of other hotels and hotel rooms can be a bit of a muchness.
# Raffles isn't.
# With the refurbishment I really do hope they keep the essence of the hotel...More
# 3
# We were informed prior to our arrival that there would be some renovations taking place at the hotel but not to the degree that there was. 3/4 of the hotel was closed leaving just 1 bar and dining area available. All facilities such as pool/Spa...More
# 4
# I only had the chance to get a Singapore sling at the Long Bar, but since my last visit , more than 25 years ago, nothing looks changed, his service and charm is always top level. Don't miss it!
# thanks
# 5
# ...

# %%
for m in [1,2,3,5,6]:
    print(m)
# Out:
# 1
# 2
# 3
# 5
# 6

# %%
j=1
for link in soup.find_all("div",{"class","rating reviewItemInline"}):
    print(j)
    #pint(link)
    #pint(link.find_all('span')[0])
    print(link.find_all('span')[0].attr['class'][1])
    print(link.find_all('span')[1].attr['title'])
    j=j+1
# Out:
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-d8069b415716> in <module>()
#       4     #pint(link)
#       5     #pint(link.find_all('span')[0])
# ----> 6     print(link.find_all('span')[0].attr['class'][1])
#       7     print(link.find_all('span')[1].attr['title'])
#       8     j=j+1
#
# TypeError: 'NoneType' object is not subscriptable

# %%
j=1
set1=[]
for link in soup.find_all("div",{"class":"review-container"}):
    set1.append(link.find('p').text)
    j=j+1
    
print(type(set1),len(set1))
# Out:
# <class 'list'> 5
